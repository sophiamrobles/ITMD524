# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
# (My Code from ITMD 522 - HW#2)

# import pandas as pd.
import pandas as pd
import numpy as np
from pathlib import Path

# Folder path: '/Users/harshpatel/Desktop/MS-ITM/ITMD 524/project_dataset'
folder_path = Path('/Users/harshpatel/Desktop/MS-ITM/ITMD 524/project_dataset')  

# Read the excel file and specific 'Data' spreadsheet from CSV file. Get all CSV files in the folder.
# pandas.read_csv(filepath_or_buffer, *, sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=<no_default>, skip_blank_lines=True, parse_dates=None, infer_datetime_format=<no_default>, keep_date_col=<no_default>, date_parser=<no_default>, date_format=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors='strict', dialect=None, on_bad_lines='error', delim_whitespace=<no_default>, low_memory=True, memory_map=False, float_precision=None, storage_options=None, dtype_backend=<no_default>)
# csv_files = [f for f in folder_path.glob('*.csv') if 'Small' in f.name]
csv_files = [f for f in folder_path.glob('*.csv') if 'Small' in f.name]

# To assign names for each datafile as a dataframe.
for file in csv_files:
    var_name = file.stem.replace(" ", "_").replace("-", "_")
    globals()[var_name] = pd.read_csv(file)
    print(f"Loaded: {var_name} (shape: {globals()[var_name].shape})")
# Out:
# Loaded: HI_Small_Trans (shape: (5078345, 11))
# Loaded: LI_Small_Trans (shape: (6924049, 11))

# %% [markdown]
# # HI_Small_Trans dataset.

# %%
LI_Small_Trans
# Out:
#                 Timestamp  From Bank    Account  To Bank  Account.1  \
# 0        2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1        2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2        2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3        2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4        2022/09/01 00:00         20  8006AD530       20  8006AD530
# ...                   ...        ...        ...      ...        ...
# 6924044  2022/09/10 23:39      71696  81B2518F1    71528  81C0482E1
# 6924045  2022/09/10 23:48     271241  81B567481   173457  81C0DA751
# 6924046  2022/09/10 23:50     271241  81B567481   173457  81C0DA751
# 6924047  2022/09/10 23:57     170558  81A2206B1   275798  81C1D5CA1
# 6924048  2022/09/10 23:31     170558  81A2206B1   275798  81C1D5CA1
#
#          Amount Received Receiving Currency   Amount Paid Payment Currency  \
# 0           3.195403e+06          US Dollar  3.195403e+06        US Dollar
# 1           1.858960e+03          US Dollar  1.858960e+03        US Dollar
# 2           5.925710e+05          US Dollar  5.925710e+05        US Dollar
# 3           1.232000e+01          US Dollar  1.232000e+01        US Dollar
# 4           2.941560e+03          US Dollar  2.941560e+03        US Dollar
# ...                  ...                ...           ...              ...
# 6924044     3.346900e-02            Bitcoin  3.346900e-02          Bitcoin
# 6924045     1.313000e-03            Bitcoin  1.313000e-03          Bitcoin
# 6924046     1.305800e-02            Bitcoin  1.305800e-02          Bitcoin
# 6924047     4.145370e-01            Bitcoin  4.145370e-01          Bitcoin
# 6924048     3.427700e-02            Bitcoin  3.427700e-02          Bitcoin
#
#         Payment Format  Is Laundering
# 0         Reinvestment              0
# 1         Reinvestment              0
# 2               Cheque              0
# 3         Reinvestment              0
# 4         Reinvestment              0
# ...                ...            ...
# 6924044        Bitcoin              0
# 6924045        Bitcoin              0
# 6924046        Bitcoin              0
# 6924047        Bitcoin              0
# 6924048        Bitcoin              0
#
# [6924049 rows x 11 columns]

# %% [markdown]
# # LI_Small_Trans dataset.

# %%
HI_Small_Trans
# Out:
#                 Timestamp  From Bank    Account  To Bank  Account.1  \
# 0        2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1        2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2        2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3        2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4        2022/09/01 00:06         10  8000F5200       10  8000F5200
# ...                   ...        ...        ...      ...        ...
# 5078340  2022/09/10 23:57      54219  8148A6631   256398  8148A8711
# 5078341  2022/09/10 23:35         15  8148A8671   256398  8148A8711
# 5078342  2022/09/10 23:52     154365  8148A6771   256398  8148A8711
# 5078343  2022/09/10 23:46     256398  8148A6311   256398  8148A8711
# 5078344  2022/09/10 23:37     154518  8148A6091   256398  8148A8711
#
#          Amount Received Receiving Currency   Amount Paid Payment Currency  \
# 0            3697.340000          US Dollar   3697.340000        US Dollar
# 1               0.010000          US Dollar      0.010000        US Dollar
# 2           14675.570000          US Dollar  14675.570000        US Dollar
# 3            2806.970000          US Dollar   2806.970000        US Dollar
# 4           36682.970000          US Dollar  36682.970000        US Dollar
# ...                  ...                ...           ...              ...
# 5078340         0.154978            Bitcoin      0.154978          Bitcoin
# 5078341         0.108128            Bitcoin      0.108128          Bitcoin
# 5078342         0.004988            Bitcoin      0.004988          Bitcoin
# 5078343         0.038417            Bitcoin      0.038417          Bitcoin
# 5078344         0.281983            Bitcoin      0.281983          Bitcoin
#
#         Payment Format  Is Laundering
# 0         Reinvestment              0
# 1               Cheque              0
# 2         Reinvestment              0
# 3         Reinvestment              0
# 4         Reinvestment              0
# ...                ...            ...
# 5078340        Bitcoin              0
# 5078341        Bitcoin              0
# 5078342        Bitcoin              0
# 5078343        Bitcoin              0
# 5078344        Bitcoin              0
#
# [5078345 rows x 11 columns]

# %% [markdown]
# # Merge two dataset.

# %%
merged_Small_df = pd.concat([LI_Small_Trans, HI_Small_Trans], ignore_index=True)
display(merged_Small_df)
display(merged_Small_df.info())
display(merged_Small_df.nunique())
value_counts = merged_Small_df['Is Laundering'].value_counts()
print(value_counts)

merged_Small_df = merged_Small_df[merged_Small_df['Receiving Currency'] == 'US Dollar']
merged_Small_df
# Out:
#                  Timestamp  From Bank    Account  To Bank  Account.1  \
# 0         2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1         2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2         2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3         2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4         2022/09/01 00:00         20  8006AD530       20  8006AD530
# ...                    ...        ...        ...      ...        ...
# 12002389  2022/09/10 23:57      54219  8148A6631   256398  8148A8711
# 12002390  2022/09/10 23:35         15  8148A8671   256398  8148A8711
# 12002391  2022/09/10 23:52     154365  8148A6771   256398  8148A8711
# 12002392  2022/09/10 23:46     256398  8148A6311   256398  8148A8711
# 12002393  2022/09/10 23:37     154518  8148A6091   256398  8148A8711
#
#           Amount Received Receiving Currency   Amount Paid Payment Currency  \
# 0            3.195403e+06          US Dollar  3.195403e+06        US Dollar
# 1            1.858960e+03          US Dollar  1.858960e+03        US Dollar
# 2            5.925710e+05          US Dollar  5.925710e+05        US Dollar
# 3            1.232000e+01          US Dollar  1.232000e+01        US Dollar
# 4            2.941560e+03          US Dollar  2.941560e+03        US Dollar
# ...                   ...                ...           ...              ...
# 12002389     1.549780e-01            Bitcoin  1.549780e-01          Bitcoin
# 12002390     1.081280e-01            Bitcoin  1.081280e-01          Bitcoin
# 12002391     4.988000e-03            Bitcoin  4.988000e-03          Bitcoin
# 12002392     3.841700e-02            Bitcoin  3.841700e-02          Bitcoin
# 12002393     2.819830e-01            Bitcoin  2.819830e-01          Bitcoin
#
#          Payment Format  Is Laundering
# 0          Reinvestment              0
# 1          Reinvestment              0
# 2                Cheque              0
# 3          Reinvestment              0
# 4          Reinvestment              0
# ...                 ...            ...
# 12002389        Bitcoin              0
# 12002390        Bitcoin              0
# 12002391        Bitcoin              0
# 12002392        Bitcoin              0
# 12002393        Bitcoin              0
#
# [12002394 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12002394 entries, 0 to 12002393
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Timestamp           object
#  1   From Bank           int64
#  2   Account             object
#  3   To Bank             int64
#  4   Account.1           object
#  5   Amount Received     float64
#  6   Receiving Currency  object
#  7   Amount Paid         float64
#  8   Payment Currency    object
#  9   Payment Format      object
#  10  Is Laundering       int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 1007.3+ MB
# None
# Timestamp               15133
# From Bank               57222
# Account               1166980
# To Bank                 33608
# Account.1              988911
# Amount Received       1835635
# Receiving Currency         15
# Amount Paid           1850741
# Payment Currency           15
# Payment Format              7
# Is Laundering               2
# dtype: int64
# 0    11993652
# 1        8742
# Name: Is Laundering, dtype: int64
#                  Timestamp  From Bank    Account  To Bank  Account.1  \
# 0         2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1         2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2         2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3         2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4         2022/09/01 00:00         20  8006AD530       20  8006AD530
# ...                    ...        ...        ...      ...        ...
# 11999923  2022/09/10 23:53      21575  802146470   138133  814468C00
# 11999924  2022/09/10 23:49     115359  80E121C00    35036  8144B5CD0
# 11999925  2022/09/10 23:33      12735  80170F410   241742  8147B1930
# 11999926  2022/09/10 23:51      12735  80170F410   241742  8147B1930
# 11999927  2022/09/10 23:42      18679  807951C10   253359  814901FB0
#
#           Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0              3195403.00          US Dollar   3195403.00        US Dollar
# 1                 1858.96          US Dollar      1858.96        US Dollar
# 2               592571.00          US Dollar    592571.00        US Dollar
# 3                   12.32          US Dollar        12.32        US Dollar
# 4                 2941.56          US Dollar      2941.56        US Dollar
# ...                   ...                ...          ...              ...
# 11999923           228.60          US Dollar       228.60        US Dollar
# 11999924           796.30          US Dollar       796.30        US Dollar
# 11999925           200.43          US Dollar       200.43        US Dollar
# 11999926           251.97          US Dollar       251.97        US Dollar
# 11999927             9.30          US Dollar         9.30        US Dollar
#
#          Payment Format  Is Laundering
# 0          Reinvestment              0
# 1          Reinvestment              0
# 2                Cheque              0
# 3          Reinvestment              0
# 4          Reinvestment              0
# ...                 ...            ...
# 11999923    Credit Card              0
# 11999924    Credit Card              0
# 11999925         Cheque              0
# 11999926            ACH              0
# 11999927         Cheque              0
#
# [4416583 rows x 11 columns]

# %% [markdown]
# # X independent and Y dependent variable.

# %%
# Define a function to extract last 4 characters from account (as string)
def last_4_digits(val):
    if pd.isna(val):
        return 'UNK'  # For missing values
    return str(val)[-4:]

# Apply it to high-cardinality object columns
merged_Small_df['Account_Grouped'] = merged_Small_df['Account'].apply(last_4_digits)
merged_Small_df['Account1_Grouped'] = merged_Small_df['Account.1'].apply(last_4_digits)

X = merged_Small_df.drop(columns='Is Laundering')
y = merged_Small_df['Is Laundering']

print("X:\n")
display(X)

print("Y:\n")
display(y)
# Out:
# X:
#                  Timestamp  From Bank    Account  To Bank  Account.1  \
# 0         2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1         2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2         2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3         2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4         2022/09/01 00:00         20  8006AD530       20  8006AD530
# ...                    ...        ...        ...      ...        ...
# 11999923  2022/09/10 23:53      21575  802146470   138133  814468C00
# 11999924  2022/09/10 23:49     115359  80E121C00    35036  8144B5CD0
# 11999925  2022/09/10 23:33      12735  80170F410   241742  8147B1930
# 11999926  2022/09/10 23:51      12735  80170F410   241742  8147B1930
# 11999927  2022/09/10 23:42      18679  807951C10   253359  814901FB0
#
#           Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0              3195403.00          US Dollar   3195403.00        US Dollar
# 1                 1858.96          US Dollar      1858.96        US Dollar
# 2               592571.00          US Dollar    592571.00        US Dollar
# 3                   12.32          US Dollar        12.32        US Dollar
# 4                 2941.56          US Dollar      2941.56        US Dollar
# ...                   ...                ...          ...              ...
# 11999923           228.60          US Dollar       228.60        US Dollar
# 11999924           796.30          US Dollar       796.30        US Dollar
# 11999925           200.43          US Dollar       200.43        US Dollar
# 11999926           251.97          US Dollar       251.97        US Dollar
# 11999927             9.30          US Dollar         9.30        US Dollar
#
#          Payment Format Account_Grouped Account1_Grouped
# 0          Reinvestment            CA90             CA90
# 1          Reinvestment            DAD0             DAD0
# 2                Cheque            CA90             A910
# 3          Reinvestment            D080             D080
# 4          Reinvestment            D530             D530
# ...                 ...             ...              ...
# 11999923    Credit Card            6470             8C00
# 11999924    Credit Card            1C00             5CD0
# 11999925         Cheque            F410             1930
# 11999926            ACH            F410             1930
# 11999927         Cheque            1C10             1FB0
#
# [4416583 rows x 12 columns]
# Y:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 11999923    0
# 11999924    0
# 11999925    0
# 11999926    0
# 11999927    0
# Name: Is Laundering, Length: 4416583, dtype: int64

# %% [markdown]
# # Things I did for X.
#
# - Convert Timestamp into columns like i.e., {hour, day, weekday, and month}.
# - For Account_Grouped and Account1_Grouped columns,
#     - Extract first two letters (if present)
#     - Collect the digits at the end (whatever part is numeric)

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import re

# Drop redundant columns
X = X.drop(columns=['Account', 'Account.1'])

# Convert string to datetime
X['timestamp_column_name'] = pd.to_datetime(X['Timestamp'])

# Extract datetime features
X['hour'] = X['timestamp_column_name'].dt.hour
X['day'] = X['timestamp_column_name'].dt.day
X['weekday'] = X['timestamp_column_name'].dt.weekday
X['month'] = X['timestamp_column_name'].dt.month

X = X.drop(['Timestamp'], axis=1)

# One-hot encode selected categorical columns
categorical_cols = ['Receiving Currency', 'Payment Currency', 'Payment Format']

encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
encoded_array = encoder.fit_transform(X[categorical_cols])

encoded_df = pd.DataFrame(
    encoded_array,
    columns=encoder.get_feature_names_out(categorical_cols),
    index=X.index
)

X = pd.concat([X.drop(columns=categorical_cols), encoded_df], axis=1)

def fast_encode_account_grouped(df, column_name, prefix):
    col = df[column_name].astype(str).str.strip()

    # Extract first two letters
    letters = col.str.extract(r'([A-Za-z])?([A-Za-z])?')
    digits = col.str.extract(r'(\d+)')

    l1 = letters[0].str.upper().apply(lambda x: ord(x) - ord('A') if pd.notnull(x) else -1)
    l2 = letters[1].str.upper().apply(lambda x: ord(x) - ord('A') if pd.notnull(x) else -1)
    num = digits[0].fillna(-1).astype(int)

    return pd.DataFrame({
        f'{prefix}_L1': l1,
        f'{prefix}_L2': l2,
        f'{prefix}_Num': num
    }, index=df.index)

# Apply vectorized encoding
X = pd.concat([
    X,
    fast_encode_account_grouped(X, 'Account_Grouped', 'AG'),
    fast_encode_account_grouped(X, 'Account1_Grouped', 'AG1')
], axis=1)

X.drop(columns=['Account_Grouped', 'Account1_Grouped'], inplace=True)
X
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#           From Bank  To Bank  Amount Received  Amount Paid  \
# 0                11       11       3195403.00   3195403.00
# 1              3402     3402          1858.96      1858.96
# 2                11     1120        592571.00    592571.00
# 3              3814     3814            12.32        12.32
# 4                20       20          2941.56      2941.56
# ...             ...      ...              ...          ...
# 11999923      21575   138133           228.60       228.60
# 11999924     115359    35036           796.30       796.30
# 11999925      12735   241742           200.43       200.43
# 11999926      12735   241742           251.97       251.97
# 11999927      18679   253359             9.30         9.30
#
#          timestamp_column_name  hour  day  weekday  month  \
# 0          2022-09-01 00:08:00     0    1        3      9
# 1          2022-09-01 00:21:00     0    1        3      9
# 2          2022-09-01 00:00:00     0    1        3      9
# 3          2022-09-01 00:16:00     0    1        3      9
# 4          2022-09-01 00:00:00     0    1        3      9
# ...                        ...   ...  ...      ...    ...
# 11999923   2022-09-10 23:53:00    23   10        5      9
# 11999924   2022-09-10 23:49:00    23   10        5      9
# 11999925   2022-09-10 23:33:00    23   10        5      9
# 11999926   2022-09-10 23:51:00    23   10        5      9
# 11999927   2022-09-10 23:42:00    23   10        5      9
#
#           Receiving Currency_US Dollar  ...  Payment Format_Cheque  \
# 0                                  1.0  ...                    0.0
# 1                                  1.0  ...                    0.0
# 2                                  1.0  ...                    1.0
# 3                                  1.0  ...                    0.0
# 4                                  1.0  ...                    0.0
# ...                                ...  ...                    ...
# 11999923                           1.0  ...                    0.0
# 11999924                           1.0  ...                    0.0
# 11999925                           1.0  ...                    1.0
# 11999926                           1.0  ...                    0.0
# 11999927                           1.0  ...                    1.0
#
#           Payment Format_Credit Card  Payment Format_Reinvestment  \
# 0                                0.0                          1.0
# 1                                0.0                          1.0
# 2                                0.0                          0.0
# 3                                0.0                          1.0
# 4                                0.0                          1.0
# ...                              ...                          ...
# 11999923                         1.0                          0.0
# 11999924                         1.0                          0.0
# 11999925                         0.0                          0.0
# 11999926                         0.0                          0.0
# 11999927                         0.0                          0.0
#
#           Payment Format_Wire  AG_L1  AG_L2  AG_Num  AG1_L1  AG1_L2  AG1_Num
# 0                         0.0      2      0      90       2       0       90
# 1                         0.0      3      0       0       3       0        0
# 2                         0.0      2      0      90       0      -1      910
# 3                         0.0      3     -1      80       3      -1       80
# 4                         0.0      3     -1     530       3      -1      530
# ...                       ...    ...    ...     ...     ...     ...      ...
# 11999923                  0.0     -1     -1    6470      -1      -1        8
# 11999924                  0.0     -1     -1       1      -1      -1        5
# 11999925                  0.0      5     -1     410      -1      -1     1930
# 11999926                  0.0      5     -1     410      -1      -1     1930
# 11999927                  0.0     -1     -1       1      -1      -1        1
#
# [4416583 rows x 38 columns]

# %%
y
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 11999923    0
# 11999924    0
# 11999925    0
# 11999926    0
# 11999927    0
# Name: Is Laundering, Length: 4416583, dtype: int64

# %% [markdown]
# # Now, Oversample (SMOTE) and Undersample Majority Class.
#
# - We will get new balanced data -- X and y.

# %%
# Identify datetime columns
datetime_cols = X.select_dtypes(include=['datetime64']).columns
print(datetime_cols)

# Convert them into numeric features (like year, month, etc.)
for col in datetime_cols:
    X[f'{col}_year'] = X[col].dt.year
    X[f'{col}_month'] = X[col].dt.month
    X[f'{col}_day'] = X[col].dt.day
    X[f'{col}_minute'] = X[col].dt.minute
    # drop original datetime column
    X.drop(columns=col, inplace=True)
    
X
# Out:
# Index(['timestamp_column_name'], dtype='object')
#           From Bank  To Bank  Amount Received  Amount Paid  hour  day  \
# 0                11       11       3195403.00   3195403.00     0    1
# 1              3402     3402          1858.96      1858.96     0    1
# 2                11     1120        592571.00    592571.00     0    1
# 3              3814     3814            12.32        12.32     0    1
# 4                20       20          2941.56      2941.56     0    1
# ...             ...      ...              ...          ...   ...  ...
# 11999923      21575   138133           228.60       228.60    23   10
# 11999924     115359    35036           796.30       796.30    23   10
# 11999925      12735   241742           200.43       200.43    23   10
# 11999926      12735   241742           251.97       251.97    23   10
# 11999927      18679   253359             9.30         9.30    23   10
#
#           weekday  month  Receiving Currency_US Dollar  \
# 0               3      9                           1.0
# 1               3      9                           1.0
# 2               3      9                           1.0
# 3               3      9                           1.0
# 4               3      9                           1.0
# ...           ...    ...                           ...
# 11999923        5      9                           1.0
# 11999924        5      9                           1.0
# 11999925        5      9                           1.0
# 11999926        5      9                           1.0
# 11999927        5      9                           1.0
#
#           Payment Currency_Australian Dollar  ...  AG_L1  AG_L2  AG_Num  \
# 0                                        0.0  ...      2      0      90
# 1                                        0.0  ...      3      0       0
# 2                                        0.0  ...      2      0      90
# 3                                        0.0  ...      3     -1      80
# 4                                        0.0  ...      3     -1     530
# ...                                      ...  ...    ...    ...     ...
# 11999923                                 0.0  ...     -1     -1    6470
# 11999924                                 0.0  ...     -1     -1       1
# 11999925                                 0.0  ...      5     -1     410
# 11999926                                 0.0  ...      5     -1     410
# 11999927                                 0.0  ...     -1     -1       1
#
#           AG1_L1  AG1_L2  AG1_Num  timestamp_column_name_year  \
# 0              2       0       90                        2022
# 1              3       0        0                        2022
# 2              0      -1      910                        2022
# 3              3      -1       80                        2022
# 4              3      -1      530                        2022
# ...          ...     ...      ...                         ...
# 11999923      -1      -1        8                        2022
# 11999924      -1      -1        5                        2022
# 11999925      -1      -1     1930                        2022
# 11999926      -1      -1     1930                        2022
# 11999927      -1      -1        1                        2022
#
#           timestamp_column_name_month  timestamp_column_name_day  \
# 0                                   9                          1
# 1                                   9                          1
# 2                                   9                          1
# 3                                   9                          1
# 4                                   9                          1
# ...                               ...                        ...
# 11999923                            9                         10
# 11999924                            9                         10
# 11999925                            9                         10
# 11999926                            9                         10
# 11999927                            9                         10
#
#           timestamp_column_name_minute
# 0                                    8
# 1                                   21
# 2                                    0
# 3                                   16
# 4                                    0
# ...                                ...
# 11999923                            53
# 11999924                            49
# 11999925                            33
# 11999926                            51
# 11999927                            42
#
# [4416583 rows x 41 columns]

# %%
print(X.dtypes)

# Normalization on X
# y is already normalized.
from sklearn.preprocessing import MinMaxScaler

original_columns = X.columns

scaler = MinMaxScaler()
X = scaler.fit_transform(X)  # Returns a NumPy array

# Optionally convert back to DataFrame (to keep column names)
X = pd.DataFrame(X, columns=original_columns)

X
# Out:
# From Bank                               int64
# To Bank                                 int64
# Amount Received                       float64
# Amount Paid                           float64
# hour                                    int64
# day                                     int64
# weekday                                 int64
# month                                   int64
# Receiving Currency_US Dollar          float64
# Payment Currency_Australian Dollar    float64
# Payment Currency_Bitcoin              float64
# Payment Currency_Brazil Real          float64
# Payment Currency_Canadian Dollar      float64
# Payment Currency_Euro                 float64
# Payment Currency_Mexican Peso         float64
# Payment Currency_Ruble                float64
# Payment Currency_Rupee                float64
# Payment Currency_Saudi Riyal          float64
# Payment Currency_Shekel               float64
# Payment Currency_Swiss Franc          float64
# Payment Currency_UK Pound             float64
# Payment Currency_US Dollar            float64
# Payment Currency_Yen                  float64
# Payment Currency_Yuan                 float64
# Payment Format_ACH                    float64
# Payment Format_Bitcoin                float64
# Payment Format_Cash                   float64
# Payment Format_Cheque                 float64
# Payment Format_Credit Card            float64
# Payment Format_Reinvestment           float64
# Payment Format_Wire                   float64
# AG_L1                                   int64
# AG_L2                                   int64
# AG_Num                                  int64
# AG1_L1                                  int64
# AG1_L2                                  int64
# AG1_Num                                 int64
# timestamp_column_name_year              int64
# timestamp_column_name_month             int64
# timestamp_column_name_day               int64
# timestamp_column_name_minute            int64
# dtype: object
#          From Bank   To Bank  Amount Received   Amount Paid  hour       day  \
# 0         0.000029  0.000029     1.922555e-04  1.922555e-04   0.0  0.000000
# 1         0.009025  0.009025     1.118461e-07  1.118467e-07   0.0  0.000000
# 2         0.000029  0.002971     3.565279e-05  3.565279e-05   0.0  0.000000
# 3         0.010118  0.010118     7.406468e-10  7.412357e-10   0.0  0.000000
# 4         0.000053  0.000053     1.769821e-07  1.769827e-07   0.0  0.000000
# ...            ...       ...              ...           ...   ...       ...
# 4416578   0.057237  0.366461     1.375341e-08  1.375400e-08   1.0  0.529412
# 4416579   0.306041  0.092949     4.790980e-08  4.791039e-08   1.0  0.529412
# 4416580   0.033785  0.641331     1.205852e-08  1.205911e-08   1.0  0.529412
# 4416581   0.033785  0.641331     1.515949e-08  1.516008e-08   1.0  0.529412
# 4416582   0.049554  0.672150     5.589446e-10  5.595336e-10   1.0  0.529412
#
#           weekday  month  Receiving Currency_US Dollar  \
# 0        0.500000    0.0                           0.0
# 1        0.500000    0.0                           0.0
# 2        0.500000    0.0                           0.0
# 3        0.500000    0.0                           0.0
# 4        0.500000    0.0                           0.0
# ...           ...    ...                           ...
# 4416578  0.833333    0.0                           0.0
# 4416579  0.833333    0.0                           0.0
# 4416580  0.833333    0.0                           0.0
# 4416581  0.833333    0.0                           0.0
# 4416582  0.833333    0.0                           0.0
#
#          Payment Currency_Australian Dollar  ...     AG_L1     AG_L2  \
# 0                                       0.0  ...  0.500000  0.166667
# 1                                       0.0  ...  0.666667  0.166667
# 2                                       0.0  ...  0.500000  0.166667
# 3                                       0.0  ...  0.666667  0.000000
# 4                                       0.0  ...  0.666667  0.000000
# ...                                     ...  ...       ...       ...
# 4416578                                 0.0  ...  0.000000  0.000000
# 4416579                                 0.0  ...  0.000000  0.000000
# 4416580                                 0.0  ...  1.000000  0.000000
# 4416581                                 0.0  ...  1.000000  0.000000
# 4416582                                 0.0  ...  0.000000  0.000000
#
#            AG_Num    AG1_L1    AG1_L2   AG1_Num  timestamp_column_name_year  \
# 0        0.009009  0.500000  0.166667  0.009009                         0.0
# 1        0.000000  0.666667  0.166667  0.000000                         0.0
# 2        0.009009  0.166667  0.000000  0.091091                         0.0
# 3        0.008008  0.666667  0.000000  0.008008                         0.0
# 4        0.053053  0.666667  0.000000  0.053053                         0.0
# ...           ...       ...       ...       ...                         ...
# 4416578  0.647648  0.000000  0.000000  0.000801                         0.0
# 4416579  0.000100  0.000000  0.000000  0.000501                         0.0
# 4416580  0.041041  0.000000  0.000000  0.193193                         0.0
# 4416581  0.041041  0.000000  0.000000  0.193193                         0.0
# 4416582  0.000100  0.000000  0.000000  0.000100                         0.0
#
#          timestamp_column_name_month  timestamp_column_name_day  \
# 0                                0.0                   0.000000
# 1                                0.0                   0.000000
# 2                                0.0                   0.000000
# 3                                0.0                   0.000000
# 4                                0.0                   0.000000
# ...                              ...                        ...
# 4416578                          0.0                   0.529412
# 4416579                          0.0                   0.529412
# 4416580                          0.0                   0.529412
# 4416581                          0.0                   0.529412
# 4416582                          0.0                   0.529412
#
#          timestamp_column_name_minute
# 0                            0.135593
# 1                            0.355932
# 2                            0.000000
# 3                            0.271186
# 4                            0.000000
# ...                               ...
# 4416578                      0.898305
# 4416579                      0.830508
# 4416580                      0.559322
# 4416581                      0.864407
# 4416582                      0.711864
#
# [4416583 rows x 41 columns]

# %% [markdown]
# # Split the dataset.

# %%
from sklearn.model_selection import train_test_split

# Source: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
# Example: X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, # X scalered data.
                                                    y, # y
                                                    test_size=0.25, # test_size : float or int, default=None
                                                    random_state=42, # random_state : int, RandomState instance or None, default=None
                                                    shuffle=True, # shuffle : bool, default=True
                                                    stratify=y) # stratify : array-like, default=None

# %%
# Show the training dataset. X_train and y_train.
display("The predict_cols_scaled_df_X_train dataset: \n", X_train)
# y_train
display("\n\nThe predict_cols_scaled_df_y_train dataset: \n", y_train)
# Out:
# 'The predict_cols_scaled_df_X_train dataset: \n'
#          From Bank   To Bank  Amount Received   Amount Paid      hour  \
# 2525241   0.003266  0.004346     5.414363e-09  5.414951e-09  0.913043
# 2871850   0.004247  0.047034     1.539071e-07  1.539077e-07  0.739130
# 293977    0.074553  0.021505     4.304169e-07  4.304174e-07  0.347826
# 701992    0.568024  0.334219     3.750344e-08  3.750403e-08  0.347826
# 118896    0.937393  0.937398     1.386592e-08  1.386651e-08  0.000000
# ...            ...       ...              ...           ...       ...
# 201513    0.000186  0.072251     2.474753e-07  2.474759e-07  0.086957
# 320757    0.029992  0.321026     4.347269e-06  4.347269e-06  0.391304
# 3447726   0.002982  0.056397     5.584633e-09  5.585222e-09  0.347826
# 541588    0.300348  0.352960     2.517116e-08  2.517175e-08  0.956522
# 1382154   0.000003  0.041872     3.418467e-08  3.418526e-08  1.000000
#
#               day   weekday  month  Receiving Currency_US Dollar  \
# 2525241  0.529412  0.833333    0.0                           0.0
# 2871850  0.000000  0.500000    0.0                           0.0
# 293977   0.000000  0.500000    0.0                           0.0
# 701992   0.058824  0.666667    0.0                           0.0
# 118896   0.000000  0.500000    0.0                           0.0
# ...           ...       ...    ...                           ...
# 201513   0.000000  0.500000    0.0                           0.0
# 320757   0.000000  0.500000    0.0                           0.0
# 3447726  0.235294  0.000000    0.0                           0.0
# 541588   0.000000  0.500000    0.0                           0.0
# 1382154  0.235294  0.000000    0.0                           0.0
#
#          Payment Currency_Australian Dollar  ...     AG_L1  AG_L2    AG_Num  \
# 2525241                                 0.0  ...  0.000000    0.0  0.380380
# 2871850                                 0.0  ...  0.000000    0.0  0.005105
# 293977                                  0.0  ...  0.000000    0.0  0.003804
# 701992                                  0.0  ...  0.333333    1.0  0.003003
# 118896                                  0.0  ...  0.000000    0.0  0.604605
# ...                                     ...  ...       ...    ...       ...
# 201513                                  0.0  ...  0.333333    0.0  0.066066
# 320757                                  0.0  ...  0.833333    1.0  0.004004
# 3447726                                 0.0  ...  0.000000    0.0  0.002102
# 541588                                  0.0  ...  0.333333    1.0  0.000000
# 1382154                                 0.0  ...  0.000000    0.0  0.000801
#
#            AG1_L1    AG1_L2   AG1_Num  timestamp_column_name_year  \
# 2525241  0.333333  0.000000  0.002002                         0.0
# 2871850  1.000000  0.000000  0.000501                         0.0
# 293977   0.000000  0.000000  0.000400                         0.0
# 701992   0.333333  0.833333  0.000000                         0.0
# 118896   0.000000  0.000000  0.604605                         0.0
# ...           ...       ...       ...                         ...
# 201513   0.000000  0.000000  0.140140                         0.0
# 320757   0.166667  0.000000  0.000200                         0.0
# 3447726  0.000000  0.000000  0.000400                         0.0
# 541588   0.666667  1.000000  0.000000                         0.0
# 1382154  0.333333  0.000000  0.000601                         0.0
#
#          timestamp_column_name_month  timestamp_column_name_day  \
# 2525241                          0.0                   0.529412
# 2871850                          0.0                   0.000000
# 293977                           0.0                   0.000000
# 701992                           0.0                   0.058824
# 118896                           0.0                   0.000000
# ...                              ...                        ...
# 201513                           0.0                   0.000000
# 320757                           0.0                   0.000000
# 3447726                          0.0                   0.235294
# 541588                           0.0                   0.000000
# 1382154                          0.0                   0.235294
#
#          timestamp_column_name_minute
# 2525241                      0.237288
# 2871850                      1.000000
# 293977                       0.491525
# 701992                       0.508475
# 118896                       0.440678
# ...                               ...
# 201513                       0.813559
# 320757                       0.966102
# 3447726                      0.305085
# 541588                       0.983051
# 1382154                      0.898305
#
# [3312437 rows x 41 columns]
# '\n\nThe predict_cols_scaled_df_y_train dataset: \n'
# 6890979    0
# 7822472    0
# 793845     0
# 1904688    0
# 119066     0
#           ..
# 542207     0
# 864019     0
# 9380625    0
# 1461421    0
# 3764731    0
# Name: Is Laundering, Length: 3312437, dtype: int64

# %%
# Show the testing dataset. X_test and y_test.
display("The predict_cols_scaled_df_X_test dataset: \n", X_test)
# y_test
display("\n\nThe predict_cols_scaled_df_y_test dataset: \n", y_test)
# Out:
# 'The predict_cols_scaled_df_X_test dataset: \n'
#          From Bank   To Bank  Amount Received   Amount Paid      hour  \
# 1850519   0.571897  0.391335     1.257475e-10  1.263365e-10  0.956522
# 1457928   0.031225  0.314855     5.214069e-08  5.214128e-08  0.260870
# 4215973   0.000032  0.001361     2.562590e-07  2.562596e-07  0.478261
# 2849150   0.000186  0.333474     4.679973e-08  4.680032e-08  0.652174
# 320782    0.004348  0.031751     1.387338e-07  1.387344e-07  0.391304
# ...            ...       ...              ...           ...       ...
# 628143    0.582122  0.051014     9.916183e-07  9.916189e-07  0.130435
# 477475    0.029307  0.029307     9.727869e-07  9.727875e-07  0.826087
# 3186028   0.000584  0.003428     9.783517e-08  9.783576e-08  0.869565
# 1577953   0.005011  0.050889     1.266717e-07  1.266722e-07  0.826087
# 2421608   0.000053  0.075941     1.663585e-07  1.663591e-07  1.000000
#
#               day   weekday  month  Receiving Currency_US Dollar  \
# 1850519  0.352941  0.333333    0.0                           0.0
# 1457928  0.294118  0.166667    0.0                           0.0
# 4215973  0.470588  0.666667    0.0                           0.0
# 2849150  0.000000  0.500000    0.0                           0.0
# 320782   0.000000  0.500000    0.0                           0.0
# ...           ...       ...    ...                           ...
# 628143   0.058824  0.666667    0.0                           0.0
# 477475   0.000000  0.500000    0.0                           0.0
# 3186028  0.058824  0.666667    0.0                           0.0
# 1577953  0.294118  0.166667    0.0                           0.0
# 2421608  0.470588  0.666667    0.0                           0.0
#
#          Payment Currency_Australian Dollar  ...     AG_L1  AG_L2    AG_Num  \
# 1850519                                 0.0  ...  0.000000    0.0  0.008909
# 1457928                                 0.0  ...  0.000000    0.0  0.002202
# 4215973                                 0.0  ...  0.000000    0.0  0.007307
# 2849150                                 0.0  ...  0.000000    0.0  0.866867
# 320782                                  0.0  ...  0.000000    0.0  0.640641
# ...                                     ...  ...       ...    ...       ...
# 628143                                  0.0  ...  0.833333    0.0  0.000400
# 477475                                  0.0  ...  0.000000    0.0  0.000901
# 3186028                                 0.0  ...  0.000000    0.0  0.138138
# 1577953                                 0.0  ...  0.500000    0.0  0.050050
# 2421608                                 0.0  ...  0.000000    0.0  0.000100
#
#            AG1_L1    AG1_L2   AG1_Num  timestamp_column_name_year  \
# 1850519  0.000000  0.000000  0.000801                         0.0
# 1457928  0.500000  0.000000  0.000000                         0.0
# 4215973  0.166667  0.666667  0.009009                         0.0
# 2849150  0.000000  0.000000  0.907908                         0.0
# 320782   0.000000  0.000000  0.000701                         0.0
# ...           ...       ...       ...                         ...
# 628143   1.000000  0.666667  0.003003                         0.0
# 477475   0.000000  0.000000  0.000901                         0.0
# 3186028  0.000000  0.000000  0.000601                         0.0
# 1577953  0.000000  0.000000  0.000000                         0.0
# 2421608  0.833333  0.000000  0.000501                         0.0
#
#          timestamp_column_name_month  timestamp_column_name_day  \
# 1850519                          0.0                   0.352941
# 1457928                          0.0                   0.294118
# 4215973                          0.0                   0.470588
# 2849150                          0.0                   0.000000
# 320782                           0.0                   0.000000
# ...                              ...                        ...
# 628143                           0.0                   0.058824
# 477475                           0.0                   0.000000
# 3186028                          0.0                   0.058824
# 1577953                          0.0                   0.294118
# 2421608                          0.0                   0.470588
#
#          timestamp_column_name_minute
# 1850519                      0.338983
# 1457928                      0.796610
# 4215973                      0.796610
# 2849150                      1.000000
# 320782                       0.830508
# ...                               ...
# 628143                       0.932203
# 477475                       0.186441
# 3186028                      0.169492
# 1577953                      0.305085
# 2421608                      0.067797
#
# [1104146 rows x 41 columns]
# '\n\nThe predict_cols_scaled_df_y_test dataset: \n'
# 5042370     0
# 3971796     0
# 11461726    0
# 7758181     0
# 864044      0
#            ..
# 1697283     0
# 1295984     0
# 8671168     0
# 4301769     0
# 6605762     0
# Name: Is Laundering, Length: 1104146, dtype: int64

# %% [markdown]
# # Balance the train dataset.

# %%
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.utils import shuffle
from joblib import Parallel, delayed
import numpy as np
import pandas as pd

# Create a valid SMOTEENN instance with actual SMOTE
def create_smoteenn():
    return SMOTEENN(
        sampling_strategy='auto',
        random_state=42,
        smote=SMOTE(k_neighbors=3, n_jobs=-1),  # ✅ must be SMOTE
        enn=EditedNearestNeighbours(n_neighbors=3, n_jobs=-1),
        n_jobs=-1
    )

# Process one batch safely
def process_batch(X_batch, y_batch, i):
    try:
        sme = create_smoteenn()
        X_res, y_res = sme.fit_resample(X_batch, y_batch)
        print(f"✅ Batch {i+1} done")
        return X_res, y_res
    except Exception as e:
        print(f"⚠️ Skipping batch {i+1}: {e}")
        return None

# Main function: parallel + SMOTEENN
def batchwise_smoteenn_fast(X, y, batch_size=200000, n_jobs=-1):
    # Optional shuffle to randomize order
    X, y = shuffle(X, y, random_state=42)

    # Convert to NumPy for slicing
    X_np = X.values if isinstance(X, pd.DataFrame) else X
    y_np = y.values if isinstance(y, pd.Series) else y

    num_rows = len(X_np)
    num_batches = (num_rows + batch_size - 1) // batch_size

    # Prepare batches
    batches = [
        (X_np[i * batch_size : min((i + 1) * batch_size, num_rows)],
         y_np[i * batch_size : min((i + 1) * batch_size, num_rows)], i)
        for i in range(num_batches)
    ]

    print(f"🚀 Starting parallel processing with {num_batches} batches...")

    # Run in parallel
    results = Parallel(n_jobs=n_jobs)(
        delayed(process_batch)(*args) for args in batches
    )

    # Filter out failed batches
    X_resampled_list = [r[0] for r in results if r is not None]
    y_resampled_list = [r[1] for r in results if r is not None]

    if not X_resampled_list:
        raise ValueError("All batches failed. Nothing to concatenate.")

    # Combine
    X_final = np.vstack(X_resampled_list)
    y_final = np.hstack(y_resampled_list)

    # Convert back to DataFrame/Series if needed
    if isinstance(X, pd.DataFrame):
        X_final = pd.DataFrame(X_final, columns=X.columns)
    if isinstance(y, pd.Series):
        y_final = pd.Series(y_final, name=y.name)

    print("✅ All batches processed and combined.")
    return X_final, y_final

X_train, y_train = batchwise_smoteenn_fast(X_train, y_train, batch_size=200000, n_jobs=4)

X_train
# Out:
# 🚀 Starting parallel processing with 17 batches...
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# ✅ All batches processed and combined.
#          From Bank   To Bank  Amount Received   Amount Paid      hour  \
# 0         0.585165  0.585168     1.039854e-08  8.051437e-09  0.652174
# 1         0.000003  0.041638     9.207244e-09  9.207833e-09  0.565217
# 2         0.030464  0.050149     3.270638e-09  3.271227e-09  0.130435
# 3         0.013636  0.323889     7.506825e-07  7.506831e-07  0.782609
# 4         0.008354  0.052340     1.194541e-07  1.194547e-07  0.478261
# ...            ...       ...              ...           ...       ...
# 6619799   0.029943  0.116815     1.602844e-07  1.602850e-07  0.750782
# 6619800   0.023933  0.031221     1.765698e-04  1.765698e-04  0.267540
# 6619801   0.292039  0.003439     5.451523e-07  5.451529e-07  0.164014
# 6619802   0.055666  0.034483     1.033232e-06  1.033233e-06  0.490232
# 6619803   0.002969  0.001113     8.033528e-08  8.033586e-08  0.582870
#
#               day   weekday  month  Receiving Currency_US Dollar  \
# 0        0.176471  1.000000    0.0                           0.0
# 1        0.176471  1.000000    0.0                           0.0
# 2        0.352941  0.333333    0.0                           0.0
# 3        0.058824  0.666667    0.0                           0.0
# 4        0.470588  0.666667    0.0                           0.0
# ...           ...       ...    ...                           ...
# 6619799  0.440753  0.582134    0.0                           0.0
# 6619800  0.284425  0.139204    0.0                           0.0
# 6619801  0.172006  0.987352    0.0                           0.0
# 6619802  0.722079  0.212556    0.0                           0.0
# 6619803  0.588235  1.000000    0.0                           0.0
#
#          Payment Currency_Australian Dollar  ...     AG_L1     AG_L2  \
# 0                                       0.0  ...  0.833333  0.000000
# 1                                       0.0  ...  0.000000  0.000000
# 2                                       0.0  ...  0.500000  0.000000
# 3                                       0.0  ...  0.166667  1.000000
# 4                                       0.0  ...  0.000000  0.000000
# ...                                     ...  ...       ...       ...
# 6619799                                 0.0  ...  0.460133  0.000000
# 6619800                                 0.0  ...  0.109849  0.027462
# 6619801                                 0.0  ...  0.462055  0.000000
# 6619802                                 0.0  ...  0.137669  0.000000
# 6619803                                 0.0  ...  0.027067  0.000000
#
#            AG_Num    AG1_L1  AG1_L2   AG1_Num  timestamp_column_name_year  \
# 0        0.087087  0.833333     0.0  0.087087                         0.0
# 1        0.857858  0.000000     0.0  0.408408                         0.0
# 2        0.045045  0.000000     0.0  0.008008                         0.0
# 3        0.007007  0.000000     0.0  0.009710                         0.0
# 4        0.000701  0.000000     0.0  0.391391                         0.0
# ...           ...       ...     ...       ...                         ...
# 6619799  0.022593  0.666667     0.0  0.067294                         0.0
# 6619800  0.001403  0.666667     0.0  0.083214                         0.0
# 6619801  0.035182  0.154018     0.0  0.000678                         0.0
# 6619802  0.009864  0.000000     0.0  0.000683                         0.0
# 6619803  0.703111  0.153133     0.0  0.000760                         0.0
#
#          timestamp_column_name_month  timestamp_column_name_day  \
# 0                                0.0                   0.176471
# 1                                0.0                   0.176471
# 2                                0.0                   0.352941
# 3                                0.0                   0.058824
# 4                                0.0                   0.470588
# ...                              ...                        ...
# 6619799                          0.0                   0.440753
# 6619800                          0.0                   0.284425
# 6619801                          0.0                   0.172006
# 6619802                          0.0                   0.722079
# 6619803                          0.0                   0.588235
#
#          timestamp_column_name_minute
# 0                            1.000000
# 1                            0.677966
# 2                            0.135593
# 3                            0.440678
# 4                            0.949153
# ...                               ...
# 6619799                      0.697750
# 6619800                      0.898113
# 6619801                      0.624319
# 6619802                      0.406035
# 6619803                      0.391641
#
# [6619804 rows x 41 columns]

# %%
y_train
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 6619799    1
# 6619800    1
# 6619801    1
# 6619802    1
# 6619803    1
# Name: Is Laundering, Length: 6619804, dtype: int64

# %% [markdown]
# # Compute the weight to y_train as we already balanced it in the earlier code.

# %%
from sklearn.utils.class_weight import compute_class_weight

# numpy.ravel(a, order='C') : Return a contiguous flattened array.
# A 1-D array, containing the elements of the input, is returned. A copy is made only if needed.
y_train = y_train.values.ravel()

# https://scikit-learn.org/stable/modules/generated/sklearn.utils.class_weight.compute_class_weight.html
# sklearn.utils.class_weight.compute_class_weight(class_weight, *, classes, y)
# Returns: class_weight_vect : ndarray of shape (n_classes,) : Array with class_weight_vect[i] the weight for i-th class.
temp_compute_class_weight = compute_class_weight(class_weight="balanced", # class_weight : dict, “balanced” or None
                                                 classes=np.unique(y_train), # classes : ndarray
                                                 y=y_train) # y : array-like of shape (n_samples,)

# Classification and weighting.
tempResClassWeight = {tempIdx: tempData1 for tempIdx, tempData1 in zip(np.unique(y_train, 
                                                                                 return_index=False, 
                                                                                 return_inverse=False, 
                                                                                 return_counts=False, 
                                                                                 axis=None, 
                                                                                 equal_nan=True), 
                                                                      temp_compute_class_weight)}

# Show weight.
tempResClassWeight
# Out:
# {0: 0.9999972808936555, 1: 1.0000027191211318}

# %% [markdown]
# # So, now, Data Processing work over. It's the most important step. Otherwise, we won't get best results. Now, off to 5 models to test.

# %%
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, roc_auc_score

# Source: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.htmls
# sklearn.metrics.make_scorer(score_func, *, response_method='default', greater_is_better=True, **kwargs)
# Make a scorer from a performance metric or loss function.
# A scorer is a wrapper around an arbitrary metric or loss function that is called with the signature scorer(estimator, X, y_true, **kwargs).
# It is accepted in all scikit-learn estimators or functions allowing a scoring parameter.
# The parameter response_method allows to specify which method of the estimator should be used to feed the scoring/loss function.
# response_method{“predict_proba”, “decision_function”, “predict”} or list/tuple of such str, default=None
# metrics_score_list = {
#     # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
#     'accuracy_score' : make_scorer(accuracy_score),
#     # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
#     'precision_score' : make_scorer(precision_score),
#     # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.htmls
#     'recall_scores' : make_scorer(recall_score),
#     # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
#     'roc_auc_score' : make_scorer(roc_auc_score),
# }

metrics_score_list = ['accuracy', # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
                      # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
                      'precision', 
                      # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.htmls
                      'recall', 
                      # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
                      'roc_auc',
                      # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
                     'f1']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# # Model-4: GradientBoostingClassifier techniques (AUC ROC + Accurcay + F1)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html
# class sklearn.ensemble.GradientBoostingClassifier(*, loss='log_loss', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)
clf_GBC = GradientBoostingClassifier(loss='log_loss', 
                                     learning_rate=0.1, 
                                     n_estimators=100, 
                                     subsample=1.0, 
                                     criterion='friedman_mse', 
                                     min_samples_split=2, 
                                     min_samples_leaf=1, 
                                     min_weight_fraction_leaf=0.0, 
                                     max_depth=3, 
                                     min_impurity_decrease=0.0, 
                                     init=None, 
                                     random_state=42, 
                                     max_features=None, 
                                     verbose=0, 
                                     max_leaf_nodes=None, 
                                     warm_start=False, 
                                     validation_fraction=0.1, 
                                     n_iter_no_change=None, 
                                     tol=0.0001, 
                                     ccp_alpha=0.0)

# estimator details for GradientBoostingr.
# https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html
clf_GBC_pipeline = Pipeline([
    ('clf_GBC', 
     clf_GBC) # GradientBoostingClassifier
])

# Parameter details for GradientBoostingr.
# param_grid : dict or list of dictionaries
clf_GBC_param_grid = {
    # The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance. Values must be in the range [1, inf).
    'clf_GBC__n_estimators': [50, 
                              100], 
    # Learning rate shrinks the contribution of each tree by learning_rate.
    'clf_GBC__learning_rate': [0.05,
                               0.1],
    # Maximum depth of the individual regression estimators. 
    'clf_GBC__max_depth': [3, 
                           10],  
    # The minimum number of samples required to split an internal node.
    'clf_GBC__min_samples_split': [2, 
                                   5], 
    # The minimum number of samples required to be at a leaf node.
    'clf_GBC__min_samples_leaf': [1, 
                                  3]  
}

# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
# class sklearn.model_selection.GridSearchCV(estimator, param_grid, *, scoring=None, n_jobs=None, refit=True, cv=None, verbose=0, pre_dispatch='2*n_jobs', error_score=nan, return_train_score=False)
clf_grid_search = GridSearchCV(estimator=clf_GBC_pipeline,
                                   param_grid=clf_GBC_param_grid, 
                                   scoring=metrics_score_list, 
                                   cv=5, 
                                   n_jobs=4,
                                   refit=False, 
                                   verbose=1, 
                                   pre_dispatch='2*n_jobs', 
                                   return_train_score=False)

# fit(X, y=None, **params)
clf_grid_search.fit(X_train, # X
                    y_train) # y

# cv_results_dict of numpy (masked) ndarrays : A dict with keys as column headers and values as columns, that can be imported into a pandas DataFrame.
tempResCV = clf_grid_search.cv_results_
print("\n The clf_grid_search's results are: \n", clf_grid_search.cv_results_)

# AOC-RUC
print("\n\n****************************************************************************************")
print("\nBASED ON Gradient Boosting Classifier's BEST AOC-RUC PARAMETER:")
tempo_mapping_roc_auc = clf_grid_search.cv_results_['params'][tempResCV['mean_test_roc_auc'].argmax()]
print(f"\nThe Best Parameters for AUC-ROC:\n {tempo_mapping_roc_auc}")

tempo_mapping_roc_auc_model = clf_GBC_pipeline.set_params(**tempo_mapping_roc_auc).fit(X_train, # X
                                                                                 y_train) # y
tempYPred = tempo_mapping_roc_auc_model.predict(X_test)
tempYPred_probability = tempo_mapping_roc_auc_model.predict_proba(X_test)[:,
                                                                     # Probability of the positive class (class 1)
                                                                     1]
# Classification report.
# sklearn.metrics.classification_report(y_true, tempYPred, *, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=False, zero_division='warn')
print(classification_report(y_test, # y_true : 1d
                            tempYPred, # tempYPred : 1d
                            labels=None, 
                            target_names=None, 
                            sample_weight=None, 
                            digits=2, 
                            output_dict=False, 
                            zero_division='warn'))
# Get the roc_auc_score.
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
tmpAucRocScore = roc_auc_score(y_test, 
                               tempYPred_probability,
                               average='micro', 
                               sample_weight=None, 
                               max_fpr=None, 
                               multi_class='raise', 
                               labels=None)
print(f"\nThe AUC-ROC Score of the best model parameters:\n {tmpAucRocScore:.4f}")
# Test data calculations.
tmpAccuracyScore = accuracy_score(y_test, tempYPred)
print(f"\n[TEST DATA] The accuracy Score of the best model parameters:\n {tmpAccuracyScore:.4f}")
tmpF1Score = f1_score(y_test, tempYPred)
print(f"\n[TEST DATA] The F1 Score of the best model parameters:\n {tmpF1Score:.4f}")


# ACCURACY
print("\n\n****************************************************************************************")
print("\nBASED ON Gradient Boosting Classifier's BEST ACCURACY PARAMETER:")
tempo_mapping_accuracy = clf_grid_search.cv_results_['params'][tempResCV['mean_test_accuracy'].argmax()]
print(f"\nThe Best Parameters for ACCURACY:\n {tempo_mapping_accuracy}")

tempo_mapping_accuracy_model = clf_GBC_pipeline.set_params(**tempo_mapping_accuracy).fit(X_train, # X
                                                                                 y_train) # y
tempYPred = tempo_mapping_accuracy_model.predict(X_test)
tempYPred_probability = tempo_mapping_accuracy_model.predict_proba(X_test)[:,
                                                                     # Probability of the positive class (class 1)
                                                                     1]
# Classification report.
# sklearn.metrics.classification_report(y_true, tempYPred, *, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=False, zero_division='warn')
print(classification_report(y_test, # y_true : 1d
                            tempYPred, # tempYPred : 1d
                            labels=None, 
                            target_names=None, 
                            sample_weight=None, 
                            digits=2, 
                            output_dict=False, 
                            zero_division='warn'))
# Get the roc_auc_score.
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
tmpAucRocScore = roc_auc_score(y_test, 
                               tempYPred_probability,
                               average='micro', 
                               sample_weight=None, 
                               max_fpr=None, 
                               multi_class='raise', 
                               labels=None)
print(f"\nThe AUC-ROC Score of the best model parameters:\n {tmpAucRocScore:.4f}")
# Test data calculations.
tmpAccuracyScore = accuracy_score(y_test, tempYPred)
print(f"\n[TEST DATA] The accuracy Score of the best model parameters:\n {tmpAccuracyScore:.4f}")
tmpF1Score = f1_score(y_test, tempYPred)
print(f"\n[TEST DATA] The F1 Score of the best model parameters:\n {tmpF1Score:.4f}")


# F1
print("\n\n****************************************************************************************")
print("\nBASED ON Gradient Boosting Classifier's BEST F1 PARAMETER:")
tempo_mapping_f1 = clf_grid_search.cv_results_['params'][tempResCV['mean_test_f1'].argmax()]
print(f"\nThe Best Parameters for F1:\n {tempo_mapping_f1}")

tempo_mapping_f1_model = clf_GBC_pipeline.set_params(**tempo_mapping_f1).fit(X_train, # X
                                                                       y_train) # y
tempYPred = tempo_mapping_f1_model.predict(X_test)
tempYPred_probability = tempo_mapping_f1_model.predict_proba(X_test)[:,
                                                                     # Probability of the positive class (class 1)
                                                                     1]
# Classification report.
# sklearn.metrics.classification_report(y_true, tempYPred, *, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=False, zero_division='warn')
print(classification_report(y_test, # y_true : 1d
                            tempYPred, # tempYPred : 1d
                            labels=None, 
                            target_names=None, 
                            sample_weight=None, 
                            digits=2, 
                            output_dict=False, 
                            zero_division='warn'))
# Get the roc_auc_score.
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
tmpAucRocScore = roc_auc_score(y_test, 
                               tempYPred_probability,
                               average='micro', 
                               sample_weight=None, 
                               max_fpr=None, 
                               multi_class='raise', 
                               labels=None)
print(f"\n[TEST DATA] The AUC-ROC Score of the best model parameters:\n {tmpAucRocScore:.4f}")
# Test data calculations.
tmpAccuracyScore = accuracy_score(y_test, tempYPred)
print(f"\n[TEST DATA] The accuracy Score of the best model parameters:\n {tmpAccuracyScore:.4f}")
tmpF1Score = f1_score(y_test, tempYPred)
print(f"\n[TEST DATA] The F1 Score of the best model parameters:\n {tmpF1Score:.4f}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits

# %% [markdown]
# # Model-5: SVC (AUC ROC + Accurcay + F1)
